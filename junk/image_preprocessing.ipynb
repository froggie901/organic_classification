# %%
# !pip install imageio
# Out:
# ...
# You are using pip version 10.0.1, however version 19.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import numpy as np
print(np.__version__)
import pandas as pd
# Out:
# 1.16.2

# %%
import imageio as im
import numpy as np 
# import matplotlib.image as mpimg
# from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# from skimage import data
# from skimage.color import rgb2gray
import cv2

# %%
# str_ochem = im.imread('./images/1_pentene_100917166.png')

# %%
# print (str_ochem.shape)

#width, height, channel
# Out:
# (300, 300, 4)

# %%
img = cv2.imread('./images/1_pentene_12987.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imwrite('/Users/patrickcavins/Desktop/test2.png',gray)
# Out:
# True

# %%
img = cv2.imread('./images/glycerol_1030.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imwrite('/Users/patrickcavins/Desktop/test.png',gray)

str_ochem = im.imread('/Users/patrickcavins/Desktop/test.png')
print(str_ochem.shape)
x1 = list(str_ochem.reshape(300, 300, 1).ravel())

str_ochem2 = im.imread('/Users/patrickcavins/Desktop/test2.png')
print (str_ochem.shape)
x2 = list(str_ochem.reshape(300, 300, 1).ravel())
# Out:
# (300, 300)
# (300, 300)

# %%
df_row = [x1, x2]

# %%
print (df_row)
# Out:
# [[245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 245, 2
# ...

# %%
column_names = []
for i in range(1,90_001):
    name = f'p{i}'
    column_names.append(name)

x = [column_names]

# %%
len(column_names)
# Out:
# 90000

# %%
df = pd.DataFrame(columns=[column_names])
df.append(df_row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-dcb5378f8643> in <module>()
#       1 df = pd.DataFrame(columns=[column_names])
# ----> 2 df.append(df_row)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6690         return concat(to_concat, ignore_index=ignore_index,
#    6691                       verify_integrity=verify_integrity,
# -> 6692                       sort=sort)
#    6693
#    6694     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# ...

# %%
df.head()

# %%
# df.append(x)
# Out:
# Empty DataFrame
# Columns: [(p1,), (p2,), (p3,), (p4,), (p5,), (p6,), (p7,), (p8,), (p9,), (p10,), (p11,), (p12,), (p13,), (p14,), (p15,), (p16,), (p17,), (p18,), (p19,), (p20,), (p21,), (p22,), (p23,), (p24,), (p25,), (p26,), (p27,), (p28,), (p29,), (p30,), (p31,), (p32,), (p33,), (p34,), (p35,), (p36,), (p37,), (p38,), (p39,), (p40,), (p41,), (p42,), (p43,), (p44,), (p45,), (p46,), (p47,), (p48,), (p49,), (p50,), (p51,), (p52,), (p53,), (p54,), (p55,), (p56,), (p57,), (p58,), (p59,), (p60,), (p61,), (p62,), (p63,), (p64,), (p65,), (p66,), (p67,), (p68,), (p69,), (p70,), (p71,), (p72,), (p73,), (p74,), (p75,), (p76,), (p77,), (p78,), (p79,), (p80,), (p81,), (p82,), (p83,), (p84,), (p85,), (p86,), (p87,), (p88,), (p89,), (p90,), (p91,), (p92,), (p93,), (p94,), (p95,), (p96,), (p97,), (p98,), (p99,), (p100,), ...]
# Index: []
#
# [0 rows x 89999 columns]

# %%
# simple_list=[['a','b']]
# simple_list.append(['e','f'])
# test= pd.DataFrame(df_row,columns=[column_names])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-67-0069bfd9f6b9> in <module>()
#       1 # simple_list=[['a','b']]
#       2 # simple_list.append(['e','f'])
# ----> 3 test=pd.DataFrame(df_row,columns=[column_names])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433                     if is_named_tuple(data[0]) and columns is None:
#     434                         columns = data[0]._fields
# --> 435                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     436                     columns = ensure_index(columns)
#     437
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     402     if isinstance(data[0], (list, tuple)):
# ...

# %%
test.head()
# Out:
#   col1 col2
# 0    a    b
# 1    e    f

# %%
simple_list
# Out:
# [['a', 'b'], ['e', 'f']]
