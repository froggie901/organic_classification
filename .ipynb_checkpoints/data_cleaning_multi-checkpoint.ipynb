# %% [markdown]
# # data_cleaning
#
# ## By: Patrick Cavins

# %% [markdown]
# ### What needs to be done?
#
# After bringing in some initial images using the PubChem PUGRest API a coulple data munging concerns came up.
#
# - Nonstandard Isotopes
# - Two imgages in a single output file

# %%
# Import 

import pandas as pd
import requests
import os
import time
import regex as re

# %%
file_name = '2_methylbutyl_cyclopentene_134887291.csv'

# %%
df = pd.read_csv(f'./data/{file_name}')

df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.head()
# Out:
#       cid  ring                     image_saved_as
# 0   19540     1   2_methylbutyl_cyclopentene_19540
# 1   16270     1   2_methylbutyl_cyclopentene_16270
# 2   16269     1   2_methylbutyl_cyclopentene_16269
# 3  137211     1  2_methylbutyl_cyclopentene_137211
# 4   77414     1   2_methylbutyl_cyclopentene_77414

# %%
df.shape
# Out:
# (189, 3)

# %%
iupac = []
mf = []

for i in df['cid']:
    
    #Print
    print (i)
    
    #constructing the url for the specific CID 
    entry = i
    url_iupac = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/{entry}/property/IUPACName/TXT'
    url_MF = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/{entry}/property/MolecularFormula/TXT'
    
    #calling the PUG Rest PubChem API
    api_call_iupac = requests.get(url_iupac)
    api_call_MF = requests.get(url_MF)
    
    #Saving the output to a variable
    iupac_list = api_call_iupac.text
    MF_list = api_call_MF.text
    
    iupac.append(iupac_list)
    mf.append(MF_list)
    
        
    time.sleep(0.2)

#adding variables to the data frame   
df['iupac'] = iupac
df['mf'] = mf  
# df['canonical_smiles'] = smiles
# Out:
# 19540
# 16270
# 16269
# 137211
# 77414
# 521217
# 517741
# 138541
# 138257
# 137755
# 137210
# 19893859
# 6427086
# 530396
# 523528
# 523527
# 521236
# 54101622
# 20837636
# 19893766
# 19893555
# 14764015
# 6537508
# 6431020
# 6427085
# 544055
# 523530
# 523529
# 523489
# 521449
# 520404
# 520128
# 123224949
# 91199232
# 90713669
# 60007293
# 59994267
# 59954505
# 59954503
# 59954496
# 59954495
# 59954478
# 59954469
# 59954454
# 59954450
# 59954445
# 59954414
# 59936799
# 59911458
# 59911321
# 59746976
# 59117969
# 59066598
# 59039354
# 59039321
# 58688977
# 58639765
# 58504179
# 57285679
# 57198894
# 57162921
# 57125758
# 57115232
# 57045719
# 54526457
# 54252328
# 53678344
# 23384891
# 23384890
# 23267477
# 22212143
# 22129074
# 22129047
# 19893868
# 19893808
# 19893667
# 19893613
# 19893595
# 19893531
# 18730047
# 18730042
# 523526
# 129777607
# 129716583
# 124007590
# 123984630
# 123968381
# 123950095
# 123943353
# 123942691
# 123913323
# 123866552
# 123857423
# 123853415
# 123833176
# 123811136
# 123786274
# 123781570
# 123777478
# 123726806
# 123691427
# 123663745
# 123660410
# 123625055
# 123561961
# 123543629
# 123505979
# 123455735
# 123434097
# 123427642
# 123376011
# 123372890
# 123356282
# 123352159
# 123351561
# 123344000
# 123335593
# 123335256
# 123334876
# 123334091
# 123331883
# 123327315
# 123278295
# 123268931
# 123247111
# 123222009
# 123217200
# 123199909
# 123149528
# 102375905
# 102375903
# 102375902
# 91525079
# 91521521
# 91472804
# 91421460
# 91416126
# 91368966
# 91351667
# 91337363
# 91324014
# 91315313
# 91315149
# 91293975
# 91093782
# 91080148
# 90993539
# 90959296
# 90886959
# 90867074
# 90699792
# 90690533
# 85947730
# 23231120
# 20396308
# 14325896
# 14325892
# 6427196
# 6427195
# 6427193
# 6427186
# 6427722
# 6427726
# 10950624
# 11027687
# 11042899
# 11188642
# 11223190
# 14325891
# 21572738
# 21607535
# 22129060
# 22129134
# 23230863
# 56846131
# 57418697
# 57426373
# 57426379
# 57426383
# 57427588
# 57455281
# 57455282
# 91324015
# 102268007
# 102268008
# 102375904
# 124519004
# 124556686
# 134887291

# %%
df.shape
# Out:
# (189, 5)

# %%
df.to_csv(f'./data/updated/updated_{file_name}', index=False)

# %% [markdown]
# #### So this is FALSE
# ```pattern = r';'
# string = '3-methylidenepent-1-ene'
# print (re.search(pattern=pattern, string=string))```
#
# #### So this is TRUE
# ```pattern = r';'
# string = 'magnesium;pent-1-ene;bromide'
# print (re.search(pattern=pattern, string=string))```

# %%
#Start Here...

# %%
df = pd.read_csv(f'./data/updated/updated_{file_name}')

# %%
df['mf']=df['mf'].map(lambda x: x.replace('\n', ''))
df['iupac']=df['iupac'].map(lambda x: x.replace('\n', ''))

df.head()
# Out:
#       cid  ring                     image_saved_as  \
# 0   19540     1   2_methylbutyl_cyclopentene_19540
# 1   16270     1   2_methylbutyl_cyclopentene_16270
# 2   16269     1   2_methylbutyl_cyclopentene_16269
# 3  137211     1  2_methylbutyl_cyclopentene_137211
# 4   77414     1   2_methylbutyl_cyclopentene_77414
#
#                         iupac      mf
# 0          pentylcyclopentane  C10H20
# 1          propylcyclopentane   C8H16
# 2           butylcyclopentane   C9H18
# 3           decylcyclopentane  C15H30
# 4  2-methylpropylcyclopentane   C9H18

# %%
df.shape
# Out:
# (189, 5)

# %%
# pattern = r';'
# string = '3-methylidenepent-1-ene'
# bool(re.findall(pattern=pattern, string=string))

# pattern = r';'
# string = 'hex-1-ene;zinc;iodide'
# bool(re.findall(pattern=pattern, string=string))

# df_pentene.iloc[349]

# %%
#These are index values which we will want to eventually drop 
index_val = []

#Regex Pattern
pattern = r';'

#Searching to Evaluate for the IUPAC Names which contain ';' = False Positive Images
for index, row in df.iterrows():

    #using regex to find the false_positives
    if bool(re.findall(pattern=pattern, string=row[3]))==1:
        index_val.append(index)

#Identify the index values for the rows that we want to keep
indexes_to_keep =set(range(df.shape[0])) - set(index_val)
df_sliced = df.take(list(indexes_to_keep))

#Building the dataframe of false_positives
false_positives = pd.DataFrame.from_dict(dict(df.iloc[index_val]))


#Save to CSV
df_sliced.to_csv(f'./data/cleaned/cleaned_{file_name}', index=False)
false_positives.to_csv(f'./data/false_positives/false_positives_{file_name}', index=False)
    

#Print Out index list created from the for loop   
print (index_val)
print ('--'*50)
print (len(index_val))


# Inspiration, 1 = 'https://www.pythonprogramming.in/pandas-examples/how-to-append-rows-in-a-pandas-dataframe-using-a-for-loop.html'
# Inspiration, 2 = https://stackoverflow.com/questions/37727018/pandas-dataframe-move-rows-from-one-dataframe-to-another?rq=1
# Inspiration, 3 = https://stackoverflow.com/questions/14661701/how-to-drop-a-list-of-rows-from-pandas-dataframe
# Out:
# [33, 34, 172]
# ----------------------------------------------------------------------------------------------------
# 3

# %%
df_sliced.head()

print (df_sliced.shape)
# Out:
# (186, 5)

# %%
false_positives.head()
print (false_positives.shape)
# Out:
# (3, 5)

# %%
df_sliced.head()
# Out:
#       cid  ring                     image_saved_as  \
# 0   19540     1   2_methylbutyl_cyclopentene_19540
# 1   16270     1   2_methylbutyl_cyclopentene_16270
# 2   16269     1   2_methylbutyl_cyclopentene_16269
# 3  137211     1  2_methylbutyl_cyclopentene_137211
# 4   77414     1   2_methylbutyl_cyclopentene_77414
#
#                         iupac      mf
# 0          pentylcyclopentane  C10H20
# 1          propylcyclopentane   C8H16
# 2           butylcyclopentane   C9H18
# 3           decylcyclopentane  C15H30
# 4  2-methylpropylcyclopentane   C9H18

# %%
false_positives.head()
# Out:
#           cid  ring                       image_saved_as  \
# 33   91199232     1  2_methylbutyl_cyclopentene_91199232
# 34   90713669     1  2_methylbutyl_cyclopentene_90713669
# 172  22129134     1  2_methylbutyl_cyclopentene_22129134
#
#                                   iupac       mf
# 33       1,3-diethylcyclopentane;ethane   C13H30
# 34       1,3-diethylcyclopentane;ethane   C11H24
# 172  lithium;2-methylpropylcyclopentane  C9H17Li

# %%
# correct = pd.read_csv('./data/cleaned/cleaned_glycerol_137424636.csv')

# correct.head()

# %%
# sh util

# %%
len(index_val)

df_sliced.shape

false_positives = df

false_positives.head()

false_positives.shape

# indexes_to_keep = set(range(df.shape[0])) - set(indexes_to_drop)
# df_sliced = df.take(list(indexes_to_keep))


# indexes_to_keep =set(range(df.shape[0])) - set(index_val)
# df_sliced = df.take(list(indexes_to_keep))

x= dict(df.iloc[index_val])



test = pd.DataFrame.from_dict(x)

test.head()
# Out:
# 53

# %%
# df_sliced.shape
# Out:
# (292, 5)

# %%
# df.shape
# Out:
# (345, 5)

# %%
# df.drop()

# %%
# x1, y1 = df.shape

# %%
# x2, y2 = false_positives.shape

# %%
# x1-x2
# Out:
# 345

# %%
# df
# Out:
#            cid  ring       image_saved_as  \
# 0         8004     0       1_pentene_8004
# 1        11597     0      1_pentene_11597
# 2         7844     0       1_pentene_7844
# 3        11610     0      1_pentene_11610
# 4        11598     0      1_pentene_11598
# 5       639661     0     1_pentene_639661
# 6        19966     0      1_pentene_19966
# 7        11239     0      1_pentene_11239
# 8      5357259     0    1_pentene_5357259
# 9      5357258     0    1_pentene_5357258
# 10      643835     0     1_pentene_643835
# 11       12987     0      1_pentene_12987
# 12       12724     0      1_pentene_12724
# 13     5364394     0    1_pentene_5364394
# 14       66195     0      1_pentene_66195
# 15       19965     0      1_pentene_19965
# 16       18850     0      1_pentene_18850
# 17       16968     0      1_pentene_16968
# 18       12969     0      1_pentene_12969
# 19       11612     0      1_pentene_11612
# 20       11587     0      1_pentene_11587
# 21      137073     0     1_pentene_137073
# 22       67891     0      1_pentene_67891
# 23    12539503     0   1_pentene_12539503
# 24      145521     0     1_pentene_145521
# 25      144120     0     1_pentene_144120
# 26      137072     0     1_pentene_137072
# 27      136379     0     1_pentene_136379
# 28    59962855     0   1_pentene_59962855
# 29    57359528     0   1_pentene_57359528
# ..         ...   ...                  ...
# 315  101954062     0  1_pentene_101954062
# 316  101999176     0  1_pentene_101999176
# 317  101999178     0  1_pentene_101999178
# 318  101999180     0  1_pentene_101999180
# 319  102030184     0  1_pentene_102030184
# 320  102058677     0  1_pentene_102058677
# 321  102059286     0  1_pentene_102059286
# 322  102082544     0  1_pentene_102082544
# 323  102090024     0  1_pentene_102090024
# 324  102091626     0  1_pentene_102091626
# 325  102324953     0  1_pentene_102324953
# 326  102356238     0  1_pentene_102356238
# 327  102356693     0  1_pentene_102356693
# 328  102520296     0  1_pentene_102520296
# 329  102571808     0  1_pentene_102571808
# 330  102591367     0  1_pentene_102591367
# 331  102602339     0  1_pentene_102602339
# 332  122210023     0  1_pentene_122210023
# 333  122210024     0  1_pentene_122210024
# 334  122225833     0  1_pentene_122225833
# 335  124203032     0  1_pentene_124203032
# 336  131668127     0  1_pentene_131668127
# 337  135047708     0  1_pentene_135047708
# 338  135081259     0  1_pentene_135081259
# 339  135081538     0  1_pentene_135081538
# 340  135456814     0  1_pentene_135456814
# 341  136045488     0  1_pentene_136045488
# 342  136074759     0  1_pentene_136074759
# 343  136095949     0  1_pentene_136095949
# 344  137124042     0  1_pentene_137124042
#
#                                        iupac         mf
# 0                                 pent-1-ene      C5H10
# 1                                  hex-1-ene      C6H12
# 2                                  but-1-ene       C4H8
# 3                                 hept-1-ene      C7H14
# 4                             hexa-1,5-diene      C6H10
# 5                              (E)-hex-2-ene      C6H12
# 6                                  hex-2-ene      C6H12
# 7                          3-methylbut-1-ene      C5H10
# 8                             (E)-hept-3-ene      C7H14
# 9                             (Z)-hept-3-ene      C7H14
# 10                             (Z)-hex-2-ene      C6H12
# 11                   2-methylpenta-1,4-diene      C6H10
# 12                        4-methylpent-1-ene      C6H12
# 13                      (5E)-hepta-1,5-diene      C7H12
# 14                   3-methylpenta-1,4-diene      C6H10
# 15                    2-methylhexa-1,5-diene      C7H12
# 16                   3-methylidenepent-1-ene      C6H10
# 17                           hepta-1,6-diene      C7H12
# 18                        3-methylpent-1-ene      C6H12
# 19                                hept-3-ene      C7H14
# 20                           penta-1,4-diene       C5H8
# 21                    3-methylhexa-1,5-diene      C7H12
# 22                        5-fluoropent-1-ene      C5H9F
# 23                        hepta-1,2,6-triene      C7H10
# 24                         hexa-1,2,5-triene       C6H8
# 25                                 but-1-ene       C4H7
# 26                           hepta-1,5-diene      C7H12
# 27                            hexa-1,2-diene      C6H10
# 28                                 hex-1-ene      C6H10
# 29                         1-fluorohex-1-ene     C6H11F
# ..                                       ...        ...
# 315                    but-1-ene;methane;tin    C7H19Sn
# 316                  2,3-dideuteriobut-1-ene      C4H7+
# 317           1,1,4,4-tetradeuteriobut-1-ene      C4H7+
# 318        1,1,2,3,4,4-hexadeuteriobut-1-ene      C4H7+
# 319                    hex-1-ene;zinc;iodide  C6H11IZn-
# 320              aluminum;pent-1-ene;propane   C11H23Al
# 321                        hex-1-ene;lithium    C6H11Li
# 322                       hept-1-ene;lithium    C7H13Li
# 323                      2-deuteriohex-1-ene      C6H12
# 324                               pent-1-ene       C5H8
# 325                          hepta-1,6-diene     C7H11+
# 326                      hex-1-ene;zirconium    C6H11Zr
# 327   hex-1-ene;molecular hydrogen;zirconium    C6H17Zr
# 328              1,1,2-trideuteriopent-1-ene      C5H10
# 329                  pent-1-ene;zinc;bromide  C5H9BrZn-
# 330  5-deuterio-4-(deuteriomethyl)pent-1-ene      C6H12
# 331                  3,3-dideuteriobut-1-ene       C4H8
# 332                  (3R)-3-fluoropent-1-ene      C5H9F
# 333                  (3S)-3-fluoropent-1-ene      C5H9F
# 334   molecular hydrogen;pent-1-ene;titanium    C5H12Ti
# 335    1,1,2,3,3,4,4,4-octadeuteriobut-1-ene       C4H8
# 336               6,6,6-trideuteriohex-1-ene      C6H12
# 337                               hept-1-ene      C7H11
# 338                 4-methylselanylbut-1-ene    C5H10Se
# 339                5-methylselanylpent-1-ene    C6H12Se
# 340                  2-methylpenta-1,4-diene      C6H9+
# 341                       4-methylpent-1-ene     C6H11+
# 342                       3-methylpent-1-ene     C6H11+
# 343                               hept-1-ene     C7H13+
# 344                               pent-1-ene      C5H9+
#
# [345 rows x 5 columns]

# %%
false_positives
# Out:
# Empty DataFrame
# Columns: []
# Index: []
